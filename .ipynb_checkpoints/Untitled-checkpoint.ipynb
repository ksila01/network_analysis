# %%
import pandas as pd

# %%
data = pd.read_csv('MamaMbogaMoment.csv')

# %%
data.head ()
# Out:
#                       Date                                              Title  \
# 0  2022-07-19 16:47:28.000  RT @HMureithi @Kenyans This is too low for a m...
# 1  2022-07-10 16:21:50.000  RT @kilundeezy A good reminder  @OleItumbi  pa...
# 2  2022-07-10 14:36:50.000  RT @kilundeezy A good reminder  @OleItumbi  pa...
# 3  2022-07-09 15:45:27.000  RT @kilundeezy A good reminder  @OleItumbi  pa...
# 4  2022-07-09 12:34:16.000  RT @kilundeezy A good reminder  @OleItumbi  pa...
#
#                                            Full Text Sentiment Emotion  \
# 0  RT @HMureithi @Kenyans This is too low for a m...  negative     NaN
# 1  RT @kilundeezy A good reminder @OleItumbi pay ...   neutral     NaN
# 2  RT @kilundeezy A good reminder @OleItumbi pay ...   neutral     NaN
# 3  RT @kilundeezy A good reminder @OleItumbi pay ...   neutral     NaN
# 4  RT @kilundeezy A good reminder @OleItumbi pay ...   neutral     NaN
#
#         Region    Account Type        Author     City  \
# ...

# %%
data.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2396 entries, 0 to 2395
# Data columns (total 25 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    2396 non-null   object
#  1   Title                   2396 non-null   object
#  2   Full Text               2396 non-null   object
#  3   Sentiment               2396 non-null   object
#  4   Emotion                 1084 non-null   object
#  5   Region                  2128 non-null   object
#  6   Account Type            2395 non-null   object
#  7   Author                  2396 non-null   object
#  8   City                    2087 non-null   object
#  9   Full Name               2396 non-null   object
#  10  Gender                  2334 non-null   object
#  11  Hashtags                2395 non-null   object
#  12  Impact                  2396 non-null   float64
#  13  Impressions             2396 non-null   int64
# ...

# %%
# Select Relevant Columns
relevant_columns = [
    'Date','Hashtags','Full Text', 'Sentiment', 'Emotion', 'Account Type', 
    'Author', 'City', 'Full Name', 'Mentioned Authors', 
    'Professions', 'Tags', 'Twitter Followers', 'Twitter Following', 
    'Twitter Tweets', 'Reach (new)', 'Twitter Author ID',
]

# %%
# Keep only the relevant columns
cleaned_data = data[relevant_columns]
cleaned_data.head()
# Out:
#                       Date                                           Hashtags  \
# 0  2022-07-19 16:47:28.000                                   #mamambogamoment
# 1  2022-07-10 16:21:50.000  #mamambogamoment, #bottomupmuranga, #nyerinihu...
# 2  2022-07-10 14:36:50.000  #mamambogamoment, #bottomupmuranga, #nyerinihu...
# 3  2022-07-09 15:45:27.000  #mamambogamoment, #bottomupmuranga, #nyerinihu...
# 4  2022-07-09 12:34:16.000  #mamambogamoment, #bottomupmuranga, #nyerinihu...
#
#                                            Full Text Sentiment Emotion  \
# 0  RT @HMureithi @Kenyans This is too low for a m...  negative     NaN
# 1  RT @kilundeezy A good reminder @OleItumbi pay ...   neutral     NaN
# 2  RT @kilundeezy A good reminder @OleItumbi pay ...   neutral     NaN
# 3  RT @kilundeezy A good reminder @OleItumbi pay ...   neutral     NaN
# 4  RT @kilundeezy A good reminder @OleItumbi pay ...   neutral     NaN
#
# ...

# %%
cleaned_data.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2396 entries, 0 to 2395
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               2396 non-null   object
#  1   Hashtags           2395 non-null   object
#  2   Full Text          2396 non-null   object
#  3   Sentiment          2396 non-null   object
#  4   Emotion            1084 non-null   object
#  5   Account Type       2395 non-null   object
#  6   Author             2396 non-null   object
#  7   City               2087 non-null   object
#  8   Full Name          2396 non-null   object
#  9   Mentioned Authors  1433 non-null   object
#  10  Professions        523 non-null    object
#  11  Tags               2396 non-null   object
#  12  Twitter Followers  2396 non-null   int64
#  13  Twitter Following  2396 non-null   int64
#  14  Twitter Tweets     2396 non-null   int64
#  15  Reach (new)        2396 non-null   int64
# ...

# %% [markdown]
# ### Basic EDA and Data Cleaning

# %%
# Handle Missing Values
# Fill missing values with 'Unknown'
cleaned_data = cleaned_data.fillna('Unknown')

# %%
# Display basic statistics
cleaned_data.describe()
# Out:
#        Twitter Followers  Twitter Following  Twitter Tweets   Reach (new)
# count       2.396000e+03        2396.000000     2396.000000  2.396000e+03
# mean        1.093418e+04        2185.355175    20603.510851  3.929331e+03
# std         1.085441e+05        3825.394581    39850.444240  3.835713e+04
# min         0.000000e+00           0.000000        0.000000  0.000000e+00
# 25%         2.650000e+02         325.000000     1928.750000  0.000000e+00
# 50%         7.920000e+02         949.500000     6436.500000  0.000000e+00
# 75%         2.170000e+03        2537.250000    19677.750000  1.546250e+03
# max         1.657203e+06       47684.000000   390416.000000  1.186717e+06

# %%
cleaned_data.head()
# Out:
#                       Date                                           Hashtags  \
# 0  2022-07-19 16:47:28.000                                   #mamambogamoment
# 1  2022-07-10 16:21:50.000  #mamambogamoment, #bottomupmuranga, #nyerinihu...
# 2  2022-07-10 14:36:50.000  #mamambogamoment, #bottomupmuranga, #nyerinihu...
# 3  2022-07-09 15:45:27.000  #mamambogamoment, #bottomupmuranga, #nyerinihu...
# 4  2022-07-09 12:34:16.000  #mamambogamoment, #bottomupmuranga, #nyerinihu...
#
#                                            Full Text Sentiment  Emotion  \
# 0  RT @HMureithi @Kenyans This is too low for a m...  negative  Unknown
# 1  RT @kilundeezy A good reminder @OleItumbi pay ...   neutral  Unknown
# 2  RT @kilundeezy A good reminder @OleItumbi pay ...   neutral  Unknown
# 3  RT @kilundeezy A good reminder @OleItumbi pay ...   neutral  Unknown
# 4  RT @kilundeezy A good reminder @OleItumbi pay ...   neutral  Unknown
#
# ...

# %% [markdown]
# ### Distribution of Twitter Followers

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
sns.histplot(cleaned_data['Twitter Followers'], bins=30, kde=True)
plt.title('Distribution of Twitter Followers')
plt.xlabel('Number of Followers')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Interpretation
# * Highly Skewed Distribution:
#
# * The distribution of Twitter followers is highly right-skewed. This indicates that most of the authors have a relatively small number of followers.
# * A large majority of authors have a follower count near the lower end of the scale (close to zero).
# * Few Accounts with High Followers:
#
# * There are very few accounts with a very high number of followers, which is why the graph extends far to the right.These high-follower accounts are outliers compared to the majority.
# * Fruency:
#
# * The highest bar represents the number of authors with very few followers (likely below a few thousand).
# * As the number of followers increases, the frequency of such accounts decreases sharply.

# %% [markdown]
# Implications
# * Influence Concentration:
# * The influence on Twitter is likely concentrated among a few accounts with a very high number of followers.
# * These accounts may have a significant impact on the spread and reach of the hashtag #MamaMbogaMoment.
# * Role of High-Follower Accounts:
# * Identifying these high-follower accounts is crucial for understanding the key influencers in the network.
# * These accounts can be targeted for further analysis to see their role in spreading the hashtag.

# %%
# Distribution of Twitter Following:
plt.figure(figsize=(10, 6))
sns.histplot(cleaned_data['Twitter Following'], bins=30, kde=True)
plt.title('Distribution of Twitter Following')
plt.xlabel('Number of Following')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Right-Skewed Distribution:
# * Similar to the distribution of followers, the distribution of accounts that users are following is also highly right-skewed. *This indicates that most users follow a relatively small number of accounts.
# * A large majority of users follow only a few accounts (mostly near zero).
# * Few Accounts with High Following:
#
# * There are a few users who follow a very high number of accounts, which is why the graph extends far to the right.
# * These users with high following counts are outliers compared to the majority.
# * Frequency:
#
# * The highest bar represents the number of users following very few accounts (likely below a few hundred).
# * As the number of accounts being followed increases, the frequency of such users decreases sharply.

# %% [markdown]
# Implications
# * Social Reach and Engagement:
# * Users following a large number of accounts may have a different engagement pattern compared to those following fewer accounts.
# * Those who follow many accounts might be more passive consumers of content, while those following fewer accounts might be more selective and engaged.
# * Influence Dynamics:
#
# * High-following users might have different motivations for following many accounts, such as networking, staying updated, or engaging in trendjacking.
# * It’s essential to analyze whether these users with high following counts also have high followers, as it could indicate their influence and networking ability.

# %% [markdown]
# ### Top 10 Mentioned Authors

# %%
# Split the mentioned authors into individual entries
mentioned_authors = data['Mentioned Authors'].str.split(',', expand=True).stack().str.strip().value_counts().head(10)

# Plot the top 10 mentioned authors
plt.figure(figsize=(12, 8))
mentioned_authors.plot(kind='bar')
plt.title('Top 10 Mentioned Authors')
plt.xlabel('Mentioned Author')
plt.ylabel('Number of Mentions')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Interpretation
# 1. Most Mentioned Author:
#
# * The author @williamsruto has the highest number of mentions, significantly leading the chart with over 1000 mentions. This indicates that this user is a central figure in the discussions around the hashtag #MamaMbogaMoment.

# %% [markdown]
# 2. Second Most Mentioned:
# * The second most mentioned author is @railaodinga, with approximately 600 mentions. While this is considerably less than the top mentioned author, it still signifies substantial engagement.

# %% [markdown]
# 3. Other Notable Mentions:
#
# * @citizenTVKenya, @nationafrica, and @dc_kenya follow, each with progressively fewer mentions.
# * The remaining authors in the top 10 include @oleitumbi, @f_n_networks, @marthakarua, and @sakajajohnson, each having around 100 mentions or fewer.
# 4. Distribution of Mentions:
# * The distribution of mentions shows a steep decline from the first to the second author, and then a more gradual decline among the rest.
# * This suggests that while a few authors are highly prominent in the discussion, the majority of mentions are more evenly distributed among the remaining top authors.

# %% [markdown]
# #### Implications
# 1. Key Influencers:
#
# * Authors like @williamsruto and @railaodinga are likely key influencers in the discussion. Their high mention counts suggest that their tweets or posts are driving a significant portion of the conversation.
# 2. Media Influence:
#
# * Mentions of media organizations such as @citizenTVKenya and @nationafrica indicate that news coverage from these outlets might be influencing the conversation.
# 3. Political Engagement:
# * Given that several of the top-mentioned authors appear to be politicians or politically affiliated (e.g., @williamsruto, @railaodinga, @marthakarua), it indicates a strong political dimension to the hashtag's usage.

# %% [markdown]
# ### Network Data Preparation

# %%
# Combine Authors and Mentioned Authors to ensure all unique nodes are included
authors = cleaned_data[['Author', 'Twitter Followers', 'Account Type']].drop_duplicates()
mentioned_authors = cleaned_data[['Mentioned Authors']].dropna()

# %%
# Split multiple mentioned authors and clean the data
mentioned_authors = mentioned_authors['Mentioned Authors'].str.replace('@', '').str.split(', ')
mentioned_authors = mentioned_authors.explode().drop_duplicates().reset_index(drop=True)
mentioned_authors = mentioned_authors.to_frame(name='Author')

# %%
# Merge both authors and mentioned authors
all_authors = pd.merge(authors, mentioned_authors, on='Author', how='outer')
all_authors['Twitter Followers'] = all_authors['Twitter Followers'].fillna(0)
all_authors['Account Type'] = all_authors['Account Type'].fillna('Unknown')
all_authors = all_authors.drop_duplicates().reset_index(drop=True)
all_authors['Id'] = all_authors.index

# %%
# Save the Nodes file
nodes = 'nodes.csv'
all_authors.to_csv(nodes, index=False)

# %%
nodes= pd.read_csv ('nodes.csv')
nodes.head()
# Out:
#          Author  Twitter Followers Account Type  Id
# 0        mngesa               32.0   individual   0
# 1   Olang_Moses            21114.0   individual   1
# 2   Olang_Moses            20780.0   individual   2
# 3  CaesarToreto            10073.0   individual   3
# 4  CaesarToreto            10088.0   individual   4

# %%
# Step 2: Prepare Edges Data
edges = cleaned_data[['Author', 'Mentioned Authors']].dropna()
edges['Mentioned Authors'] = edges['Mentioned Authors'].str.replace('@', '').str.split(', ')
edges = edges.explode('Mentioned Authors').reset_index(drop=True)
edges = edges.rename(columns={'Author': 'Source', 'Mentioned Authors': 'Target'})

# Create a mapping of Authors to Ids
author_id_mapping = all_authors.set_index('Author')['Id'].to_dict()
edges['Source'] = edges['Source'].map(author_id_mapping)
edges['Target'] = edges['Target'].map(author_id_mapping)

# Drop rows with missing Source or Target IDs
edges = edges.dropna(subset=['Source', 'Target'])

# %%
# Save the Edges file
edges = 'edges.csv'
edges.to_csv(edges, index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 3
#       1 # Save the Edges file
#       2 edges = 'edges.csv'
# ----> 3 edges.to_csv(edges, index=False)
#
# AttributeError: 'str' object has no attribute 'to_csv'

# %% [markdown]
# * The nodes DataFrame contains information about Twitter users, including their author name, number of followers, number of following, and account type.
# * The edges DataFrame contains information about interactions between Twitter users. Each row represents a mention interaction, where a source user mentions one or more target users.

# %%
# Save nodes and edges to CSV files
nodes.to_csv('nodes.csv', index=False)
edges.to_csv('edges.csv', index=False)
